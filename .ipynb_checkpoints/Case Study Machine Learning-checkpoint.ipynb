# %% [markdown]
# ###### 1. Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ARD.com\\Documents\\Tugas akhir Machine Learning Model'

# %%
os.chdir('C:\\Users\\ARD.com\\Documents\\Tugas akhir Machine Learning Model')

# %% [markdown]
# ###### 2. Load Data

# %%
data=pd.read_csv('regression_data.csv')
data.head()
# Out:
#    gre_score  toefl_score  univ_ranking  motiv_letter_strength  \
# 0        337          118             4                    4.5
# 1        324          107             4                    4.0
# 2        316          104             3                    3.0
# 3        322          110             3                    3.5
# 4        314          103             2                    2.0
#
#    recommendation_strength   gpa  research_exp  admit_prob
# 0                      4.5  9.65             1        0.92
# 1                      4.5  8.87             1        0.76
# 2                      3.5  8.00             1        0.72
# 3                      2.5  8.67             1        0.80
# 4                      3.0  8.21             0        0.65

# %% [markdown]
# ###### 3. EDA

# %%
data.describe()
# Out:
#         gre_score  toefl_score  univ_ranking  motiv_letter_strength  \
# count  500.000000   500.000000    500.000000             500.000000
# mean   316.472000   107.192000      3.114000               3.374000
# std     11.295148     6.081868      1.143512               0.991004
# min    290.000000    92.000000      1.000000               1.000000
# 25%    308.000000   103.000000      2.000000               2.500000
# 50%    317.000000   107.000000      3.000000               3.500000
# 75%    325.000000   112.000000      4.000000               4.000000
# max    340.000000   120.000000      5.000000               5.000000
#
#        recommendation_strength         gpa  research_exp  admit_prob
# count                500.00000  500.000000    500.000000   500.00000
# mean                   3.48400    8.576440      0.560000     0.72174
# std                    0.92545    0.604813      0.496884     0.14114
# min                    1.00000    6.800000      0.000000     0.34000
# 25%                    3.00000    8.127500      0.000000     0.63000
# 50%                    3.50000    8.560000      1.000000     0.72000
# 75%                    4.00000    9.040000      1.000000     0.82000
# max                    5.00000    9.920000      1.000000     0.97000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   gre_score                500 non-null    int64
#  1   toefl_score              500 non-null    int64
#  2   univ_ranking             500 non-null    int64
#  3   motiv_letter_strength    500 non-null    float64
#  4   recommendation_strength  500 non-null    float64
#  5   gpa                      500 non-null    float64
#  6   research_exp             500 non-null    int64
#  7   admit_prob               500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
data.isnull().sum()
# Out:
# gre_score                  0
# toefl_score                0
# univ_ranking               0
# motiv_letter_strength      0
# recommendation_strength    0
# gpa                        0
# research_exp               0
# admit_prob                 0
# dtype: int64

# %%
sns.pairplot(data=data,hue='research_exp',markers=["^", "v"],palette='inferno')

# %%
correlation_between_column = data.corr()
upper_triangle_corr = np.triu(correlation_between_column)

fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(correlation_between_column, annot = True, cmap="YlGnBu",ax=ax,annot_kws={"size":15},mask=upper_triangle_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 4.Memisahkan prediktor dan target dari data

# %%
target='admit_prob'
X=data.drop(target,axis=1)
y=data[target]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2,random_state=123)

# %% [markdown]
# ###### 5.Melakukan Feature Selection

# %%
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest
selector=SelectKBest(f_regression,k=3)
selector.fit(X_train,y_train)
X_New=selector.transform(X_train)
X_New_test=selector.transform(X_test)

# %%
selector.get_support()
# Out:
# array([ True,  True, False, False, False,  True, False])

# %% [markdown]
# ###### 6.Melakukan regresi dengan linear regression

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(X_New,y_train)
# Out:
# LinearRegression()

# %%
y_pred=clf.predict(X_New_test)
y_pred
# Out:
# array([0.8141119 , 0.92187724, 0.54449394, 0.64272174, 0.82016602,
#        0.68690549, 0.88875588, 0.77517724, 0.62915251, 0.88237379,
#        0.89419195, 0.77978438, 0.94376723, 0.60915664, 0.68044553,
#        0.82113269, 0.52846651, 0.73305589, 0.92622956, 0.65174106,
#        0.55065586, 0.74319554, 0.82689674, 0.71700782, 0.84576563,
#        0.64469962, 0.58225104, 0.65859551, 0.97095155, 0.87006262,
#        0.5425746 , 0.72626795, 0.68498615, 0.6452671 , 0.49203134,
#        0.8335403 , 0.84264677, 0.76485531, 0.94849145, 0.61554671,
#        0.64943049, 0.7459292 , 0.65808055, 0.90263112, 0.78078762,
#        0.69791536, 0.67028994, 0.68189722, 0.98097411, 0.82801575,
#        0.77541674, 0.55503943, 0.62348491, 0.68219526, 0.56115209,
#        0.57290507, 0.70576641, 0.5256743 , 0.59927978, 0.69148401,
#        0.86236524, 0.83477508, 0.77719773, 0.55286659, 0.64437165,
#        0.88954824, 0.86522131, 0.82143073, 0.82806633, 0.8942505 ,
#        0.61627255, 0.7734974 , 0.6403746 , 0.83788597, 0.57208278,
#        0.93394891, 0.74002078, 0.6069552 , 0.57425561, 0.68710973,
#        0.73426338, 0.52510815, 0.89621244, 0.78140567, 0.78498892,
#        0.77532959, 0.83380176, 0.58954258, 0.70902168, 0.6632758 ,
#        0.90506542, 0.87805673, 0.70117992, 0.83438988, 0.66235306,
#        0.69728934, 0.66685239, 0.63299722, 0.76761759, 0.60106139])

# %%
clf.score(X_New_test,y_test)
# Out:
# 0.7479667142874948

# %%
clf.coef_
# Out:
# array([0.00279088, 0.00332178, 0.13518652])

# %% [markdown]
# ###### 7.Melakukan regresi dengan SVM. Gunakan kernel liniear

# %%
from sklearn.svm import SVR
clf2=SVR(kernel="linear")
clf2.fit(X_New,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred2=clf2.predict(X_New_test)
y_pred2
# Out:
# array([0.80144544, 0.91556472, 0.53948831, 0.63064467, 0.80430188,
#        0.67614588, 0.87797506, 0.77046782, 0.61802846, 0.86583339,
#        0.87745527, 0.7676388 , 0.91847844, 0.58931234, 0.68474103,
#        0.80694521, 0.51458507, 0.70223868, 0.90204935, 0.6353712 ,
#        0.53214339, 0.71926024, 0.81571066, 0.68735358, 0.84336778,
#        0.63988958, 0.5688896 , 0.64589621, 0.9635639 , 0.86584631,
#        0.53541952, 0.70154858, 0.67207709, 0.64274848, 0.47585821,
#        0.82730267, 0.83184598, 0.74915391, 0.92600166, 0.60611281,
#        0.63617678, 0.73221548, 0.65165435, 0.89399984, 0.76958158,
#        0.67544039, 0.65840187, 0.67109076, 0.97023323, 0.81211088,
#        0.76404148, 0.54505829, 0.62963339, 0.66984053, 0.55309085,
#        0.57077263, 0.6991442 , 0.49645371, 0.58763591, 0.6786762 ,
#        0.85179419, 0.81816031, 0.77557126, 0.54619797, 0.63060433,
#        0.88098484, 0.84797085, 0.80569499, 0.8126282 , 0.88263139,
#        0.59928767, 0.75997269, 0.63215079, 0.82502332, 0.55722738,
#        0.92197814, 0.73435194, 0.59581136, 0.55608771, 0.68631489,
#        0.71435048, 0.50948962, 0.88255871, 0.77295781, 0.77820414,
#        0.7642247 , 0.826753  , 0.5943933 , 0.69510529, 0.64166609,
#        0.89231049, 0.86275339, 0.69195508, 0.81959376, 0.6507761 ,
#        0.66740537, 0.65814844, 0.62272512, 0.75674981, 0.5913706 ])

# %%
clf2.score(X_New_test,y_test)
# Out:
# 0.7355657739657571

# %%
clf2.coef_
# Out:
# array([[0.00223655, 0.005796  , 0.12098878]])

# %% [markdown]
# ###### 8.Melakukan regresi dengan MLP, dengan aktivasi tanh dan 2 hidden layer sebanyak 100 dan 100

# %%
from sklearn.neural_network import MLPRegressor

# %%
clf3=MLPRegressor(hidden_layer_sizes=(100,100),activation="tanh",max_iter=1000)
clf3.fit(X_New,y_train)
# Out:
# MLPRegressor(activation='tanh', hidden_layer_sizes=(100, 100), max_iter=1000)

# %%
y_pred3=clf3.predict(X_New_test)
y_pred3
# Out:
# array([0.75214112, 0.82238145, 0.72684568, 0.65147339, 0.74332303,
#        0.7725078 , 0.79253641, 0.78600926, 0.69876091, 0.73521231,
#        0.76939005, 0.71664667, 0.74775264, 0.59483049, 0.82036135,
#        0.73017165, 0.61497019, 0.61466335, 0.7862369 , 0.62637708,
#        0.61829827, 0.64244738, 0.77241186, 0.60289765, 0.81455508,
#        0.74220804, 0.67100932, 0.68528442, 0.82457438, 0.79070962,
#        0.65570796, 0.63129945, 0.70274344, 0.79856272, 0.61933402,
#        0.80168189, 0.77124115, 0.69156058, 0.7144101 , 0.70317232,
#        0.70410894, 0.68663762, 0.79571256, 0.82204861, 0.74886908,
#        0.66063924, 0.68300182, 0.68851024, 0.82622197, 0.7682791 ,
#        0.78781062, 0.67932552, 0.78525217, 0.71006693, 0.69140831,
#        0.71010533, 0.76235742, 0.57608307, 0.59937855, 0.72863273,
#        0.77803357, 0.76991016, 0.75616805, 0.70522177, 0.67149229,
#        0.79413013, 0.78630936, 0.75150685, 0.71577848, 0.7874698 ,
#        0.62150351, 0.72049921, 0.6908457 , 0.76055788, 0.65870415,
#        0.78042039, 0.70829929, 0.62803942, 0.6369123 , 0.79539241,
#        0.66196735, 0.5787169 , 0.73589271, 0.76613849, 0.76181665,
#        0.79383402, 0.78430086, 0.77016832, 0.6877661 , 0.6990165 ,
#        0.79000193, 0.75784839, 0.73633429, 0.75729184, 0.6657005 ,
#        0.59847691, 0.70047332, 0.67088604, 0.71338923, 0.71277208])

# %%
clf3.score(X_New_test,y_test)
# Out:
# 0.34644959465113634

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error,r2_score

# %% [markdown]
# ###### 9. Melakukan evaluasi metric dengan menghitung MSE dari ketiga model regresi

# %%
regressors=[['Linear Regression :',LinearRegression()],
       ['MPL Regression:',MLPRegressor()],
       ['Support Vector Regression :',SVR()]]
reg_pred_1=[]
print('Results...\n')
for name,model in regressors:
    model=model
    model.fit(X_New,y_train)
    predictions = model.predict(X_New_test)
    rms=np.sqrt(mean_squared_error(y_test, predictions))
    reg_pred_1.append(rms)
    print(name,rms)
# Out:
# Results...
#
# Linear Regression : 0.07031238870602038
# MPL Regression: 0.9233515335885494
# Support Vector Regression : 0.09044730157410852
# C:\Users\ARD.com\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
y_ax=['Linear Regression' ,'MPL Regression', 'Support Vector Regression' ]
x_ax=reg_pred_1

# %%
sns.barplot(x=x_ax,y=y_ax,linewidth=1.5,edgecolor="0.1")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 10. Melakukan evaluasi metric dengan menghitung MAE dari ketiga model regresi

# %%
regressors=[['Linear Regression :',LinearRegression()],
       ['MPL Regression:',MLPRegressor()],
       ['Support Vector Regression :',SVR()]]
reg_pred_2=[]
print('Results...\n')
for name,model in regressors:
    model=model
    model.fit(X_New,y_train)
    predictions = model.predict(X_New_test)
    rma=np.sqrt(mean_absolute_error(y_test, predictions))
    reg_pred_2.append(rma)
    print(name,rma)
# Out:
# Results...
#
# Linear Regression : 0.21612723084888838
# MPL Regression: 0.41947820564504307
# Support Vector Regression : 0.26550460804080805
# C:\Users\ARD.com\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
y_ax=['Linear Regression' ,'MPL Regression', 'Support Vector Regression' ]
x_ax=reg_pred_2

# %%
sns.barplot(x=x_ax,y=y_ax,linewidth=1.5,edgecolor="0.1")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 11.Melakukan evaluasi metric dengan menghitung koefisien determinasi (R^2) dari ketiga model

# %%
regressors=[['Linear Regression :',LinearRegression()],
       ['MPL Regression:',MLPRegressor()],
       ['Support Vector Regression :',SVR()]]
reg_pred_3=[]
print('Results...\n')
for name,model in regressors:
    model=model
    model.fit(X_New,y_train)
    predictions = model.predict(X_New_test)
    r2=np.sqrt(r2_score(y_test, predictions))
    reg_pred_3.append(r2)
    print(name,r2)
# Out:
# Results...
#
# Linear Regression : 0.8648506890137134
# MPL Regression: 0.41668650744905245
# Support Vector Regression : 0.7635133218744703
# C:\Users\ARD.com\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
y_ax=['Linear Regression' ,'MPL Regression', 'Support Vector Regression' ]
x_ax=reg_pred_3

# %%
sns.barplot(x=x_ax,y=y_ax,linewidth=1.5,edgecolor="0.1")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###### 12. Kesimpulan

# %% [markdown]
# Dari ketiga model diatas model yang paling baik performanya yaitu model pertama (Linier Regression)
# hal ini dapat dilihat dari MAE dan MSE yang paling rendah dan R^2 paling tinggi
